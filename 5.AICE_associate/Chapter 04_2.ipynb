# %%
import numpy as np
import pandas as pd

flight = pd.read_csv('./Flight Price Prediction/Clean_Dataset.csv', encoding='cp949')

# %%
#데이터 추가하기
flight['price2'] = flight['price'] * 2
flight.insert(2, 'price3', flight['price'] * 3)

# %%
flight.head(n=10)
# Out:
#    Unnamed: 0   airline  price3   flight source_city departure_time stops  \
# 0           0  SpiceJet   17859  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet   17859  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   17868   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   17865   UK-995       Delhi        Morning  zero
# 4           4   Vistara   17865   UK-963       Delhi        Morning  zero
# 5           5   Vistara   17865   UK-945       Delhi        Morning  zero
# 6           6   Vistara   18180   UK-927       Delhi        Morning  zero
# 7           7   Vistara   18180   UK-951       Delhi      Afternoon  zero
# 8           8  GO_FIRST   17862   G8-334       Delhi  Early_Morning  zero
# 9           9  GO_FIRST   17862   G8-336       Delhi      Afternoon  zero
#
#     arrival_time destination_city    class  duration  days_left  price  price2
# ...

# %%
#데이터 삭제하기
flight.drop(columns = ['price3','price2'], axis=1, inplace = True)
flight.drop(index = [0,1,2], axis=0, inplace = True)

# %%
flight.head(10)
# Out:
#     Unnamed: 0   airline   flight source_city departure_time stops  \
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# 5            5   Vistara   UK-945       Delhi        Morning  zero
# 6            6   Vistara   UK-927       Delhi        Morning  zero
# 7            7   Vistara   UK-951       Delhi      Afternoon  zero
# 8            8  GO_FIRST   G8-334       Delhi  Early_Morning  zero
# 9            9  GO_FIRST   G8-336       Delhi      Afternoon  zero
# 10          10  GO_FIRST   G8-392       Delhi      Afternoon  zero
# 11          11  GO_FIRST   G8-338       Delhi        Morning  zero
# 12          12    Indigo  6E-5001       Delhi  Early_Morning  zero
#
#    arrival_time destination_city    class  duration  days_left  price
# 3     Afternoon           Mumbai  Economy      2.25          1   5955
# 4       Morning           Mumbai  Economy      2.33          1   5955
# ...

# %%
flight.rename(columns = {'airline' : 'airline_name', 'source_city' : 'departure_city'}, inplace = True)
flight.head(10)
# Out:
#     Unnamed: 0 airline_name   flight departure_city departure_time stops  \
# 3            3      Vistara   UK-995          Delhi        Morning  zero
# 4            4      Vistara   UK-963          Delhi        Morning  zero
# 5            5      Vistara   UK-945          Delhi        Morning  zero
# 6            6      Vistara   UK-927          Delhi        Morning  zero
# 7            7      Vistara   UK-951          Delhi      Afternoon  zero
# 8            8     GO_FIRST   G8-334          Delhi  Early_Morning  zero
# 9            9     GO_FIRST   G8-336          Delhi      Afternoon  zero
# 10          10     GO_FIRST   G8-392          Delhi      Afternoon  zero
# 11          11     GO_FIRST   G8-338          Delhi        Morning  zero
# 12          12       Indigo  6E-5001          Delhi  Early_Morning  zero
#
#    arrival_time destination_city    class  duration  days_left  price
# 3     Afternoon           Mumbai  Economy      2.25          1   5955
# ...

# %%
flight.sort_values(by = 'Unnamed: 0', ascending=True)
# Out:
#         Unnamed: 0 airline_name  flight departure_city departure_time stops  \
# 3                3      Vistara  UK-995          Delhi        Morning  zero
# 4                4      Vistara  UK-963          Delhi        Morning  zero
# 5                5      Vistara  UK-945          Delhi        Morning  zero
# 6                6      Vistara  UK-927          Delhi        Morning  zero
# 7                7      Vistara  UK-951          Delhi      Afternoon  zero
# ...            ...          ...     ...            ...            ...   ...
# 300148      300148      Vistara  UK-822        Chennai        Morning   one
# 300149      300149      Vistara  UK-826        Chennai      Afternoon   one
# 300150      300150      Vistara  UK-832        Chennai  Early_Morning   one
# 300151      300151      Vistara  UK-828        Chennai  Early_Morning   one
# 300152      300152      Vistara  UK-822        Chennai        Morning   one
#
# ...
