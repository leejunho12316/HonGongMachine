# %%
import pandas as pd
import numpy as np

# %%
df_original = pd.read_csv('Flight Price Prediction/Clean_Dataset.csv')
df_original.drop(df.columns[0], axis=1, inplace=True)
df_original.head(3)
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956

# %% [markdown]
# # Pandas로 인코딩

# %%
df['airline_encoding'] = pd.factorize(df['airline'])[0]
df.head(3)
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
#
#   destination_city    class  duration  days_left  price  airline_encoding
# 0           Mumbai  Economy      2.17          1   5953                 0
# 1           Mumbai  Economy      2.33          1   5953                 0
# 2           Mumbai  Economy      2.17          1   5956                 1

# %%
print(df['airline'].value_counts())
print(df['airline_encoding'].value_counts())
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64
# airline_encoding
# 2    127859
# 5     80892
# 4     43120
# 3     23173
# 1     16098
# 0      9011
# Name: count, dtype: int64

# %% [markdown]
# # scikit-learn으로 인코딩

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['airline_encoding_scikit_learn'] = le.fit_transform(df['airline'])
df.head(3)
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
#
#   destination_city    class  duration  days_left  price  airline_encoding  \
# 0           Mumbai  Economy      2.17          1   5953                 0
# 1           Mumbai  Economy      2.33          1   5953                 0
# 2           Mumbai  Economy      2.17          1   5956                 1
#
#    airline_encoding_scikit_learn
# 0                              4
# 1                              4
# 2                              0

# %%
print(df['airline'].value_counts())
print(df['airline_encoding_scikit_learn'].value_counts())
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64
# airline_encoding_scikit_learn
# 5    127859
# 1     80892
# 3     43120
# 2     23173
# 0     16098
# 4      9011
# Name: count, dtype: int64

# %%
le.inverse_transform(df['airline_encoding_scikit_learn']).reshape(-1,1)
# Out:
# array([['SpiceJet'],
#        ['SpiceJet'],
#        ['AirAsia'],
#        ...,
#        ['Vistara'],
#        ['Vistara'],
#        ['Vistara']], dtype=object)

# %% [markdown]
# # 원 핫 인코딩

# %%
df = df_original.copy()
df.head(5)

from sklearn.preprocessing import OneHotEncoder
oh = OneHotEncoder()

# %%
encoded = oh.fit_transform(df['class'].values.reshape(-1,1)).toarray()

# %%
df_encoded = pd.DataFrame(encoded, columns = [oh.categories_[0][0],oh.categories_[0][1]])

# %%
df1 = pd.concat([df, df_encoded], axis=1)

# %%
df1
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price  Business  \
# ...
