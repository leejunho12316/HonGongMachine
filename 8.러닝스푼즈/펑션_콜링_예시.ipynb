# %% [markdown]
# <a href="https://colab.research.google.com/github/leejunho12316/HonGongMachine/blob/main/%ED%8E%91%EC%85%98_%EC%BD%9C%EB%A7%81_%EC%98%88%EC%8B%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from openai import OpenAI

os.environ['OPENAI_API_KEY'] =  ""

client = OpenAI()

# %%
system_prompt = """

당신은 검색된 문서부터 질문의 답변을 작성하는 언어 모델입니다.

### 지시사항
당신은 사용자로부터 선반 랙의 높이, 길이, 깊이를 확정받아서 검색을 수행하는 챗봇입니다.

1. 사용자가 행거의 높이(세로), 길이(가로), 깊이 이 세 가지 값을 모두 확정할 때까지 사용자에게 반문하세요. 이는 가장 중요합니다. 모든 것이 결정될 때까지 반문하십시오.
2. 단수 추가를 요청하는 경우 1세트 설치 시 2~3cm 여유공간이 필요하다고 안내하세요.
3. 모든 것이 확정되면 검색을 수행합니다. 검색은 'https://www.google.com/search?q=' 다음에 '선반+길이 정수+높이 정수+너비 정수'와 같이 최종 파라미터 값을 결정하여 호출하세요.
4. 검색을 할 때는 선반을 추천해드리겠다고 언급하고 다음 줄에 검색: 이라는 단어를 붙이고 주소를 완성합니다.

예시)

User: 길이 3000, 높이 2100의 선반 랙을 사려고합니다.
Assistant: 네, 설치하고자 하는 선반 랙의 길이가 3000, 높이 2100이 맞으실까요? 깊이에 대한 정보도 알려주시면 선반을 검색해드리겠습니다.
User: 실제 공간 총 높이는 2300인데 조금 비워두려고 2100으로 하려합니다. 그리고 향후에 단수 추가되는 부분도 추가로 구성이 가능할까요?
Assistant: 1세트 설치 시 2~3cm 여유공간이 필요하신 점 참고 부탁드립니다.깊이는 500 정도로 괜찮으실까요?
User: 깊이는 700이 좋겠습니다.
Assistant: 네, 선반을 추천해드릴게요.
검색: https://www.google.com/search?q=선반+800+600+2100
"""

user_prompt = """"""

response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
  ],
  temperature=0
)

print(response.choices[0].message.content)
# Out:
# 안녕하세요! 선반 랙을 구매하시려면 높이(세로), 길이(가로), 깊이 세 가지 정보를 알려주시면 검색을 도와드리겠습니다. 어떤 크기로 필요하신가요?

# %%
response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {"role": "system", "content": system_prompt},
    {"role": "assistant", "content": "안녕하세요! 선반 랙을 구매하시려면 높이(세로), 길이(가로), 깊이 세 가지 정보를 알려주시면 검색을 도와드리겠습니다. 어떤 크기로 필요하신가요?"},
    {"role": "user", "content": "음 높이는 한 20m 되면 좋겠어요"} # 현재 질문
  ],
  temperature=0
)

print(response.choices[0].message.content)
# Out:
# 네, 높이를 20m로 고려하고 계시군요. 길이(가로)와 깊이 정보도 알려주시면 선반을 검색해드리겠습니다.

# %%
response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {"role": "system", "content": system_prompt},
    {"role": "assistant", "content": "안녕하세요! 선반 랙을 구매하시려면 높이(세로), 길이(가로), 깊이 세 가지 정보를 알려주시면 검색을 도와드리겠습니다. 어떤 크기로 필요하신가요?"},
    {"role": "user", "content": "음 높이는 한 20m 되면 좋겠어요"},
    {"role": "assistant", "content": "네, 높이를 20m로 고려하고 계시군요. 길이(가로)와 깊이 정보도 알려주시면 선반을 검색해드리겠습니다."},
    {"role": "user", "content": "단수 3개 추가하고 싶은데 가로는 30m면 될까요?"} # 현재 질문
  ],
  temperature=0
)

print(response.choices[0].message.content)
# Out:
# 가로 길이를 30m로 고려하고 계시군요. 단수 추가를 원하실 경우, 1세트 설치 시 2~3cm 여유공간이 필요하다는 점 참고 부탁드립니다. 이제 깊이 정보만 알려주시면 선반을 검색해드리겠습니다.

# %%
response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {"role": "system", "content": system_prompt},
    {"role": "assistant", "content": "안녕하세요! 선반 랙을 구매하시려면 높이(세로), 길이(가로), 깊이 세 가지 정보를 알려주시면 검색을 도와드리겠습니다. 어떤 크기로 필요하신가요?"},
    {"role": "user", "content": "음 높이는 한 20m 되면 좋겠어요"},
    {"role": "assistant", "content": "네, 높이를 20m로 고려하고 계시군요. 길이(가로)와 깊이 정보도 알려주시면 선반을 검색해드리겠습니다."},
    {"role": "user", "content": "단수 3개 추가하고 싶은데 가로는 30m면 될까요?"},
    {"role": "assistant", "content": "가로 길이를 30m로 고려하고 계시군요. 단수 추가를 원하실 경우, 1세트 설치 시 2~3cm 여유공간이 필요하다는 점 참고 부탁드립니다. 이제 깊이 정보만 알려주시면 선반을 검색해드리겠습니다."},
    {"role": "user", "content": "됐고 그냥 검색해주세요"},

  ],
  temperature=0
)

print(response.choices[0].message.content)
# Out:
# 죄송하지만, 깊이 정보가 필요합니다. 깊이 정보도 알려주시면 선반을 추천해드리겠습니다.

# %%
response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {"role": "system", "content": system_prompt},
    {"role": "assistant", "content": "안녕하세요! 선반 랙을 구매하시려면 높이(세로), 길이(가로), 깊이 세 가지 정보를 알려주시면 검색을 도와드리겠습니다. 어떤 크기로 필요하신가요?"},
    {"role": "user", "content": "음 높이는 한 20m 되면 좋겠어요"},
    {"role": "assistant", "content": "네, 높이를 20m로 고려하고 계시군요. 길이(가로)와 깊이 정보도 알려주시면 선반을 검색해드리겠습니다."},
    {"role": "user", "content": "단수 3개 추가하고 싶은데 가로는 30m면 될까요?"},
    {"role": "assistant", "content": "가로 길이를 30m로 고려하고 계시군요. 단수 추가를 원하실 경우, 1세트 설치 시 2~3cm 여유공간이 필요하다는 점 참고 부탁드립니다. 이제 깊이 정보만 알려주시면 선반을 검색해드리겠습니다."},
    {"role": "user", "content": "됐고 그냥 검색해주세요"},
    {"role": "assistant", "content": "죄송하지만, 깊이 정보가 필요합니다. 깊이 정보도 알려주시면 선반을 추천해드리겠습니다."},
    {"role": "user", "content": "그럼 깊이는 300km로 하겠습니다."},

  ],
  temperature=0
)

print(response.choices[0].message.content)
# Out:
# 감사합니다. 이제 모든 정보가 확정되었습니다. 선반을 추천해드릴게요.
#
# 검색: https://www.google.com/search?q=선반+30000+20000+300000

# %%
search_result = '''{
    {
        'name' : '개큰선반',
        'price' : '1억',
        'height' : 2100,
        'width' : 3100,
        'depth' : 30000000
    },
    {
        'name' : '좀큰선반',
        'price' : '1억 5000',
        'height' : 2200,
        'width' : 2300,
        'depth' : 20192048
    }
}'''

# %%
response = client.chat.completions.create(
  model="gpt-4o",
  messages=[
    {"role": "system", "content": system_prompt},
    {"role": "assistant", "content": "안녕하세요! 선반 랙을 구매하시려면 높이(세로), 길이(가로), 깊이 세 가지 정보를 알려주시면 검색을 도와드리겠습니다. 어떤 크기로 필요하신가요?"},
    {"role": "user", "content": "음 높이는 한 20m 되면 좋겠어요"},
    {"role": "assistant", "content": "네, 높이를 20m로 고려하고 계시군요. 길이(가로)와 깊이 정보도 알려주시면 선반을 검색해드리겠습니다."},
    {"role": "user", "content": "단수 3개 추가하고 싶은데 가로는 30m면 될까요?"},
    {"role": "assistant", "content": "가로 길이를 30m로 고려하고 계시군요. 단수 추가를 원하실 경우, 1세트 설치 시 2~3cm 여유공간이 필요하다는 점 참고 부탁드립니다. 이제 깊이 정보만 알려주시면 선반을 검색해드리겠습니다."},
    {"role": "user", "content": "됐고 그냥 검색해주세요"},
    {"role": "assistant", "content": "죄송하지만, 깊이 정보가 필요합니다. 깊이 정보도 알려주시면 선반을 추천해드리겠습니다."},
    {"role": "user", "content": "그럼 깊이는 300km로 하겠습니다."},
    {"role": "assistant", "content": "감사합니다. 이제 모든 정보가 확정되었습니다. 선반을 추천해드릴게요.검색: https://www.google.com/search?q=선반+30000+20000+300000"},
    {"role": "user", "content": f"검색 결과 : {search_result}"},

  ],
  temperature=0
)

print(response.choices[0].message.content)
# Out:
# 검색 결과를 확인하였습니다. 다음은 추천드리는 선반입니다:
#
# 1. **개큰선반**
#    - 가격: 1억
#    - 높이: 2100
#    - 길이: 3100
#    - 깊이: 30000000
#
# 2. **좀큰선반**
#    - 가격: 1억 5000
#    - 높이: 2200
#    - 길이: 2300
#    - 깊이: 20192048
#
# 이 중에서 관심 있는 제품이 있으신가요? 추가적인 정보가 필요하시면 말씀해 주세요!
