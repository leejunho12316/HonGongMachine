# %% [markdown]
# <a href="https://colab.research.google.com/github/leejunho12316/HonGongMachine/blob/main/QA_%ED%95%A9%EC%84%B1_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%A7%8C%EB%93%A4%EA%B8%B0_%EC%97%B0%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #합성 데이터 만들기 ㄱㄱ

# %%
import os
import json
from tqdm import tqdm
from openai import OpenAI

os.environ["OPENAI_API_KEY"] = ""

client = OpenAI()

# %%
data = [{'content': '약관 이용 가이드\n\n4. 약관의 핵심 체크항목 쉽게 찾기\n\n보험약관 핵심사항 등과 관련된 해당 조문, 쪽수 및 영상자료(QR 코드 스캔) 등을 안내드리오니, 보험회사로부터 약관을 수령한 후, 해당 내용을 반드시 확인 · 숙지 하시기 바랍니다.\n\n* QR(Quick Response)코드는 스마트폰으로 해당 QR 코드를 스캔하여 상세내용 등을 손쉽게 안내 받을 수 있습니다.\n\n보험금 지급 및 지급제한 사항\n제10조(보험금의 지급사유) P 18\n제12조(보험금을 지급하지 않는 사유) P 21\n영상자료 QR코드\n\n주의: 본인이 가입한 특약을 확인하여 가입 특약별 「보험금 지급사유 및 미지급사유」도 반드시 확인이 필요함\n\n계약 전 알릴 의무 및 위반효과\n제20조(계약 전 알릴 의무 위반의 효과) P 23\n영상자료 QR코드\n\n청약 철회\n제23조(청약의 철회) P 24\n영상자료 QR코드\n\n계약 취소\n제24조(약관교부 및 설명의무 등) P 25\n영상자료 QR코드\n\n계약 무효\n제25조(계약의 무효) P 25\n영상자료 QR코드\n\n보험료 연체 및 해지\n제33조(보험료의 납입을 연체하여 해지된 계약의 부활(효력회복)) P 28\n영상자료 QR코드\n\n부활(효력회복)\n제34조(보험료의 납입연체로 인한 해지계약의 부활(효력회복)) P 29\n영상자료 QR코드\n\n5',
  'source': 'page_5.png'},
 {'content': "약관 이용 가이드\n\n해약환급금\n제36조(계약자의 임의해지 및 피보험자의 서면동의 철회권) P 29\n제39조(해약환급금) P 30\n영상자료\n\n5. 약관을 쉽게 이용할 수 있는 꿀팁\n\n아래 5가지 꿀팁을 활용하시면 약관을 보다 쉽고 편리하게 이용할 수 있습니다.\n\n❶ 시각화된 '약관 요약내용'를 활용하시면 계약 일반사항, 가입시 유의사항, 민원사례 등 약관을 보다 쉽게 이해하실 수 있습니다. ➡ 약관 요약내용 P7~P15\n\n❷ '약관 핵심 체크항목 쉽게 찾기'를 이용하시면 약관내용 중 핵심적인 권리 및 의무관계를 보다 쉽게 찾을 수 있습니다. ➡ 핵심 체크항목 P5\n\n❸ 약관 내용 중 어려운 보험용어는 용어해설, 약관본문 Box 안 예시 등을 참고하시면 약관 이해에 도움이 됩니다. ➡ 용어해설 P16\n\n❹ '관련법규' 항목을 활용하시면 약관에서 인용한 법률 조항 및 규정을 자세히 알 수 있습니다. ➡ 부록참조\n\n❺ 약관조항 등이 음영 · 컬러화 되거나 진하게 된 경우 보험금 지급 등 약관 주요 내용이므로 주의 깊게 읽기 바랍니다.\n\n6. 기타 문의사항\n\n• 기타 문의사항은 당사 홈페이지(www.lina.co.kr), 고객 콜센터(1588-0058)로 문의 가능합니다.\n\n• 보험상품 거래단계별 필요한 금융꿀팁 또는 핵심정보 등은 금융감독원 금융소비자정보 포탈(FINE, fine.fss.or.kr)에서 확인 가능합니다.\n\n6",
  'source': 'page_6.png'},
 {'content': '시각화된 약관 요약내용 (소비자가 알아두어야 할 유의사항)\n\n1. 상품명칭 등으로 상품의 특징 이해하기\n\n상품명칭: 무배당THE 건강한치아보험V(갱신형)\n\n• 무배당은 계약자에게 배당을 하지 않는 상품을 말합니다.\n• 치아보험은 피보험자의 질병 또는 재해에 대한 위험을 보장하는 상품입니다.\n• 갱신형은 보험계약 갱신 시 연령의 증가, 위험률 변동 등으로 보험료가 인상될 수 있습니다.\n\n2. 보험금 지급 유의사항\n\n이 보험에는 면책기간, 감액지급, 보장한도 등 보험금 지급 유의사항이 설정되어 있습니다.\n보다 자세한 사항은 상품설명서 및 약관을 참조하시기 바랍니다.\n\n면책기간\n\n이 보험에는 보험금이 지급되지 않는 기간(면책기간)이 설정된 담보가 있습니다.\n\n충전치료보험금과 크라운치료보험금의 경우 가입 후 90일간 보장 제외됩니다. 단, 계약체결 시 피보험자의 보험나이가 3세 미만인 경우 계약일부터 보장됩니다.\n\n※ 갱신계약은 면책기간이 없습니다.\n\n감액지급\n\n이 보험에는 일정기간 보험금이 일부만 지급(감액지급)되는 담보가 있습니다.\n\n충전치료보험금과 크라운치료보험금의 경우 가입 후 1년간 보험금 50% 지급됩니다.\n\n※ 다만, 보험기간 중 발생한 재해로 인한 치과치료의 경우 계약일부터 해당 치료보험금의 100%를 지급합니다.\n※ 갱신계약은 감액지급이 없습니다.',
  'source': 'page_7.png'},
 {'content': '시각화된 약관 요약내용 (소비자가 알아두어야 할 유의사항)\n\n보장한도\n\n이 보험에는 보험금 지급 한도가 설정된 담보가 있습니다.\n\n담보명과 보장한도는 다음과 같습니다:\n충전치료보험금: -\n크라운치료보험금: 계약일부터 2년미만 유치·영구치 각각에 대해 연간 3개를 한도, 계약일부터 2년 이후 개수제한 없음\n\n기타 유의사항\n\n• 다음의 경우 치과치료 관련 보험금을 지급하지 않습니다.\nㄱ. 치과치료보장개시일 전에 해당 치과치료를 진단확정 받은 경우\nㄴ. 치아 교모증, 치경부 마모증, 치열교정 준비 등 "치아우식증(충치), 치주질환(잇몸질환) 또는 재해" 이외의 원인으로 치과치료를 받은 경우\nㄷ. 다른 치과치료를 위하여 임시 치과치료를 한 경우\nㄹ. 이미 충전치료, 크라운치료를 받은 부위에 대하여 새로운 "치아우식증(충치), 치주질환(잇몸질환) 또는 재해"를 원인으로 하지 않는 수리, 복구, 대체치료를 한 경우\nㅁ. 라미네이트, 잇몸성형 등 미용 상의 치료\n\n• 이미 충전치료, 크라운치료를 받은 치아에 대하여 새로운 치아우식증(충치), 치주질환(잇몸질환) 또는 재해를 직접적인 원인으로 충전치료, 크라운치료를 한 경우에는 해당 치료보험금을 지급합니다.\n\n• 동일한 치아에 대하여 동시에 충전치료, 크라운치료 중 두 가지 이상의 치과치료를 포함하는 복합형태의 치료를 받은 경우 해당 치료보험금 중 가장 높은 한가지의 해당 치료보험금을 지급합니다.\n\n3. 해약환급금에 관한 사항\n\n• 보험계약자가 보험계약을 중도에 해지할 경우 보험회사는 해약환급금을 지급합니다.\n\n해약환급금은 납입한 보험료보다 적거나 없을 수도 있습니다.\n주의: 해약환급금: 납입한 보험료에서 계약체결 · 유지관리 등에 소요되는 경비 및 경과된 기간의 위험 보장에 사용된 보험료를 차감하여 지급',
  'source': 'page_8.png'},
 {'content': '시각화된 약관 요약내용 (소비자가 알아두어야 할 유의사항)\n\n4. 갱신 시 보험료 인상 가능성\n\n• 이 보험은 갱신 시 보험료가 변동되는 갱신형 계약입니다.\n\n주의: 갱신형 계약은 갱신할 때마다 연령의 증가, 위험률 변동 등으로 보험료가 인상될 수 있으니 주의하시기 바랍니다.\n\n5. 소비자가 반드시 알아두어야 할 상품의 주요 특성\n\n보장성보험\n\n주의: \n① 이 보험은 질병 또는 재해에 대한 위험 보장을 주목적으로 하는 보장성보험이며, 저축이나 연금수령을 목적으로 가입하시기에 적합하지 않습니다.\n② 만기 또는 중도해지 시 납입한 보험료보다 환급금이 적을 수 있습니다.\n\n예금자보호제도에 관한 사항\n\n주의: 이 보험은 예금자보호법에 따라 해약환급금(또는 만기 시 보험금)에 기타지급금을 합한 금액이 1인당 "5천만원까지"(본 보험회사의 여타 보호상품과 합산) 보호됩니다. 이와 별도로 본 보험회사 보호상품의 사고보험금을 합산한 금액이 1인당 "5천만원까지" 보호됩니다.',
  'source': 'page_9.png'}]

# %%
system_prompt = '''
당신은 주어진 2개의 문서로부터 질문과 답변 쌍 5개를 생성해야 합니다.

1. 2개의 문서는 서로 이어지는 문서이므로 문맥이 순차적으로 이어지고 있습니다.
2. context는 본문이고 source는 출처입니다.
3. 주어진 2개의 문서로부터 가능한 질문과 답변의 쌍을 5개 생성하세요.
4. Q1과 A1, Q2와 A2, Q3와 A3, Q4와 A4, Q5와 A5 이렇게 작성하면 됩니다.
5. 각 답변의 뒤에는 출처 문서들을 리스트 형태로 작성하세요.
6. 주어진 문서에 없는 내용은 작성하지 마십시오. 오직 'content' 안에 있는 내용만 답변할 수 있습니다.
7. 답변은 오직 'content' 안에 있는 내용으로만 답변하지만 최대한 풍부하고 길게 작성하세요. 이는 매우 중요합니다.
8. 다수의 문서를 동시에 참고하여 답변하는 것이 가능합니다.
9. 답변할 때 문서에 해당 항목이 약관의 몇 조인지 명확한 상황이라면 답변할 때 무조건 이를 언급하면 좋겠습니다. 제10조(보험금의 지급사유)에 따르면~ 이런 것처럼 몇 조인지 언급해서 답변해주시기 바랍니다. 이는 반드시 지켜져야 합니다.
10. 너무 억지스럽게 지엽적인 질문은 금지하겠습니다. 이것은 기계독해 문제가 아닙니다. 예를 들어 아래와 같은 질문은 지양하십시오.
ex) 보험금 지급에 관한 세부규정 중, 피보험자가 장해분류표 중 동일한 재해 또는 원인으로 여러 신체부위의 장해지급률을 더하여 50% 이상인 장해상태가 되었을 경우 보험료 납입 면제 조건은 무엇인가요?
11. 위와 같이 복잡한 질문이 아니라 일반 사용자가 할만한 질문을 던지십시오.
12. 주어진 문서에서 예시, 표, 글머리 기호로 표시된 것들을 FAQ로 만드는 것을 주저하지 마십시오. 이들은 FAQ로 만들때 가장 먼저 우선순위를 가집니다. 이들이 가장 중요합니다.

예시)
입력: {'content': '약관 이용 가이드\n\n1. 보험약관이란?\n보험약관은 가입하신 보험계약의 내용 및 조건 등을 미리 정하여 놓은 계약조항으로 보험계약자와 보험회사의 권리 및 의무를 규정하고 있습니다.\n\n특히, 청약철회, 계약취소, 보험금 지급 및 지급제한 사항 등 보험계약의 중요사항에 대한 설명이 들어 있으니 반드시 확인하셔야 합니다.\n\n본 서류는 법령 및 금융소비자보호체계에 따른 절차를 거쳐 제공됩니다.\n\n2. 한 눈에 보는 약관의 구성\n약관 이용 가이드: 약관을 쉽게 잘 이용할 수 있도록 약관의 구성, 쉽게 찾는 방법 등의 내용을 담고 있는 지침서\n\n시각화된 약관 요약내용: 약관을 쉽게 잘 이용할 수 있도록 계약 주요내용 및 유의사항 등을 시각적 방법을 이용해 간단히 요약한 약관\n\n용어해설: 약관 이해를 돕기 위한 어려운 보험용어의 해설 등을 소비자에게 안내\n\n보험약관 (주계약&특약): \n- 주계약: 기본계약을 포함한 공통 사항을 정한 기본 약관\n- 특약: 주계약 외 선택 가입한 보장내용 등 필요한 사항을 정한 약관\n\n3. QR 코드를 통한 편리한 정보 이용\nQR(Quick Response) 코드란?\n스마트폰으로 해당 QR 코드를 스캔하면 상세내용 등을 손쉽게 안내받을 수 있습니다.\n\n약관해설 영상, 보험금정구시 구비서류, 회사소개 QR 코드가 제공되어 있습니다.', 'source': '약관_B00198011_1_P_page-0004.jpg'} {'content': '약관 이용 가이드\n\n4. 약관의 핵심 체크항목 쉽게 찾기\n\n보험약관 핵심사항 등과 관련된 해당 조문, 용어 및 영상자료(QR코드 스캔) 등을 안내드리오니, 보험회사로부터 약관을 수령한 후, 해당 내용을 반드시 확인·숙지 하시기 바랍니다.\n\n* QR(Quick Response)코드는 스마트폰으로 해당 QR 코드를 스캔하여 상세내용 등을 손쉽게 안내 받을 수 있습니다.\n\n보험금 지급 및 지급제한 사항: 제 10 조(보험금의 지급사유) P 18, 제 12 조(보험금을 지급하지 않는 사유) P 21, 영상자료\n\n주의! 본인이 가입한 특약을 확인하여 가입 특약별 "보험금 지급사유 및 미지급사유"도 반드시 확인이 필요함\n\n계약 전 알릴 의무 및 위반효과: 제 20 조(계약 전 알릴 의무 위반의 효과) P 23, 영상자료\n\n청약 철회: 제 23 조(청약의 철회) P 24, 영상자료\n\n계약 취소: 제 24 조(약관교부 및 설명의무 등) P 25, 영상자료\n\n계약 무효: 제 25 조(계약의 무효) P 25, 영상자료\n\n보험료 연체 및 해지: 제 33 조(보험료의 납입을 연체하여 해지된 계약의 부활(효력회복)) P 28, 영상자료\n\n부활(효력회복): 제 34 조(보험료의 납입연체로 인한 해지계약의 부활(효력회복)) P 29, 영상자료', 'source': '약관_B00198011_1_P_page-0005.jpg'} {'content': "약관 이용 가이드\n\n해약환급금\n제 36 조(계약자의 임의해지 및 피보험자의 서면동의 철회권) P 29\n제 39 조(해약환급금) P 30\n\n5. 약관을 쉽게 이용할 수 있는 꿀팁\n\n아래 5가지 꿀팁을 활용하시면 약관을 보다 쉽고 편리하게 이용할 수 있습니다.\n\n1. 시각화된 '약관 요약내용'을 활용하시면 계약 일반사항, 가입시 유의사항, 민원사례 등 약관을 보다 쉽게 이해하실 수 있습니다. → 약관 요약내용 P7~P15\n\n2. '약관 핵심 체크항목 쉽게 찾기'를 이용하시면 약관내용 중 핵심적인 권리 및 의무관계를 보다 쉽게 찾을 수 있습니다. → 핵심 체크항목 P5\n\n3. 약관 내용 중 어려운 보험용어는 용어해설, 약관본문 Box 안에서 등을 참고하시면 약관 이해에 도움이 됩니다. → 용어해설 P16\n\n4. '관련법규' 항목을 활용하시면 약관에서 인용한 법률 조항 및 규정을 자세히 알 수 있습니다. → 부록참조\n\n5. 약관조항 등이 음영·컬러화 되거나 진하게 된 경우 보험금 지급 등 약관 주요 내용이므로 주의 깊게 읽기 바랍니다.\n\n6. 기타 문의사항\n\n• 기타 문의사항은 당사 홈페이지(www.lina.co.kr), 고객 콜센터(1588-0058)로 문의 가능합니다.\n\n• 보험상품 거래단계별 필요한 금융꿀팁 또는 핵심정보 등은 금융감독원 금융소비자정보 포털(FINE, fine.fss.or.kr)에서 확인 가능합니다.\n\n6", 'source': '약관_B00198011_1_P_page-0006.jpg'}
답변:
Q1: 보험약관이란 무엇이며, 어떤 내용을 포함하고 있나요?
A1: 보험약관은 보험계약의 내용 및 조건 등을 미리 정하여 놓은 계약조항으로, 보험계약자와 보험회사의 권리 및 의무를 규정하고 있습니다. 주요 내용으로는 청약철회, 계약취소, 보험금 지급 및 지급제한 사항 등이 포함되어 있습니다.
약관의 구성은 크게 네 부분으로 나뉩니다:
1. 약관 이용 가이드: 약관의 구성, 쉽게 찾는 방법 등을 안내하는 지침서
2. 시각화된 약관 요약내용: 계약 주요내용 및 유의사항 등을 시각적 방법으로 요약
3. 용어해설: 어려운 보험용어의 해설
4. 보험약관 (주계약&특약):
   * 주계약: 기본계약을 포함한 공통 사항을 정한 기본 약관
   * 특약: 주계약 외 선택 가입한 보장내용 등 필요한 사항을 정한 약관
또한, QR 코드를 통해 약관해설 영상, 보험금 청구 시 구비서류, 회사소개 등 상세 내용을 쉽게 확인할 수 있습니다. 이 서류는 법령 및 금융소비자보호체계에 따른 절차를 거쳐 제공됩니다.
출처: ['약관_B00198011_1_P_page-0004.jpg']

Q2: 보험약관의 핵심 체크항목들은 무엇이며, 어디서 찾을 수 있나요?
A2: 보험약관의 핵심 체크항목들은 다음과 같습니다:
1. 보험금 지급 및 지급제한 사항:
   * 제10조(보험금의 지급사유) P18
   * 제12조(보험금을 지급하지 않는 사유) P21
2. 계약 전 알릴 의무 및 위반효과:
   * 제20조(계약 전 알릴 의무 위반의 효과) P23
3. 청약 철회:
   * 제23조(청약의 철회) P24
4. 계약 취소:
   * 제24조(약관교부 및 설명의무 등) P25
5. 계약 무효:
   * 제25조(계약의 무효) P25
6. 보험료 연체 및 해지:
   * 제33조(보험료의 납입을 연체하여 해지된 계약의 부활(효력회복)) P28
7. 부활(효력회복):
   * 제34조(보험료의 납입연체로 인한 해지계약의 부활(효력회복)) P29
8. 해약환급금:
   * 제36조(계약자의 임의해지 및 피보험자의 서면동의 철회권) P29
   * 제39조(해약환급금) P30
각 항목에 대해 QR 코드를 스캔하면 영상자료를 통해 상세내용을 확인할 수 있습니다. 특히, 본인이 가입한 특약을 확인하여 가입 특약별 "보험금 지급사유 및 미지급사유"도 반드시 확인해야 합니다.
출처: ['약관_B00198011_1_P_page-0005.jpg', '약관_B00198011_1_P_page-0006.jpg']

Q3: 약관을 쉽게 이용할 수 있는 방법들은 무엇인가요?
A3: 약관을 쉽게 이용할 수 있는 5가지 꿀팁이 제공되고 있습니다:
1. 시각화된 '약관 요약내용' 활용: 계약 일반사항, 가입시 유의사항, 민원사례 등 약관을 보다 쉽게 이해할 수 있습니다. (약관 요약내용 P7~P15)
2. '약관 핵심 체크항목 쉽게 찾기' 이용: 약관내용 중 핵심적인 권리 및 의무관계를 보다 쉽게 찾을 수 있습니다. (핵심 체크항목 P5)
3. 용어해설 참고: 약관 내용 중 어려운 보험용어는 용어해설, 약관본문 Box 안에서 등을 참고하면 약관 이해에 도움이 됩니다. (용어해설 P16)
4. '관련법규' 항목 활용: 약관에서 인용한 법률 조항 및 규정을 자세히 알 수 있습니다. (부록참조)
5. 음영·컬러화 또는 진하게 표시된 부분 주의: 약관조항 등이 음영·컬러화 되거나 진하게 된 경우 보험금 지급 등 약관 주요 내용이므로 주의 깊게 읽어야 합니다.
추가로, 기타 문의사항은 보험회사 홈페이지(www.lina.co.kr)나 고객 콜센터(1588-0058)를 통해 문의할 수 있습니다. 또한, 보험상품 거래단계별 필요한 금융꿀팁 또는 핵심정보 등은 금융감독원 금융소비자정보 포털(FINE, fine.fss.or.kr)에서 확인 가능합니다.
출처: ['약관_B00198011_1_P_page-0006.jpg']


'''

# %%
#user_prompt : 데이터를 두 쌍씩 묶은 데이터.
user_prompt_list = []
for i in range(len(data) - 1):
  user_prompt = "입력 : " + str(data[i]) + '\n' + str(data[i+1])
  user_prompt_list.append(user_prompt)

QA_data_result = []
file_path = 'results.jsonl'
previous_qa = ""

with open(file_path, 'w', encoding='utf-8') as file:
  for user_prompt in tqdm(user_prompt_list):

    #중복 데이터 생성 안하도록 처리
    if len(previous_qa) > 1:
      user_prompt = user_prompt + "\n단, 아래의 질문과 답변 쌍을 이미 가지고 있는 데이터입니다. 아래의 내용과 중복되거나 유사한 질문 답변 쌍은 필요없습니다.\n" + previous_qa

    #LLM 호출
    answer = client.chat.completions.create(
        model = 'gpt-4-1106-preview',
        messages = [
            {'role' : 'system', 'content' : system_prompt},
            {'role' : 'user', 'content' : user_prompt}
        ],
        temperature = 0
    )
    text = answer.choices[0].message.content

    #결과 업데이트
    QA_data_result.append(text)
    #중복 데이터 생성 안하도록 처리
    previous_qa = text

    #JSON?
    json.dump(text, file, ensure_ascii=False)
    file.write('\n')
    file.flush()
# Out:
# 100%|██████████| 4/4 [02:09<00:00, 32.37s/it]

# %%
for d in QA_data_result:
  print(d)
  print()
# Out:
# Q1: 보험약관에서 보험금 지급사유와 지급하지 않는 사유는 어떤 조항에서 확인할 수 있나요?
# A1: 보험약관에서 보험금 지급사유는 제10조(보험금의 지급사유) P18에서, 보험금을 지급하지 않는 사유는 제12조(보험금을 지급하지 않는 사유) P21에서 확인할 수 있습니다. 또한, 이와 관련된 영상자료는 QR 코드를 스캔하여 확인할 수 있습니다. 가입한 특약별로도 "보험금 지급사유 및 미지급사유"를 확인하는 것이 필요합니다.
# 출처: ['page_5.png']
#
# Q2: 계약 전 알릴 의무 위반의 효과는 어느 조항에서 찾아볼 수 있나요?
# A2: 계약 전 알릴 의무 위반의 효과는 제20조(계약 전 알릴 의무 위반의 효과) P23에서 찾아볼 수 있으며, 이에 대한 영상자료는 QR 코드를 통해 확인할 수 있습니다.
# 출처: ['page_5.png']
#
# Q3: 청약 철회와 계약 취소에 대한 정보는 어디에서 확인할 수 있나요?
# A3: 청약 철회에 대한 정보는 제23조(청약의 철회) P24에서, 계약 취소에 대한 정보는 제24조(약관교부 및 설명의무 등) P25에서 확인할 수 있습니다. 각각의 조항에 대한 영상자료는 QR 코드를 스캔하여 볼 수 있습니다.
# 출처: ['page_5.png']
#
# Q4: 보험료 연체로 인한 계약 해지와 부활(효력회복)에 대한 조항은 어디에 있나요?
# A4: 보험료 연체로 인한 계약 해지에 대한 조항은 제33조(보험료의 납입을 연체하여 해지된 계약의 부활(효력회복)) P28에, 부활(효력회복)에 대한 조항은 제34조(보험료의 납입연체로 인한 해지계약의 부활(효력회복)) P29에 있습니다. 이에 대한 영상자료는 QR 코드를 통해 확인할 수 있습니다.
# 출처: ['page_5.png']
#
# Q5: 약관을 쉽게 이용할 수 있는 꿀팁에는 어떤 것들이 있나요?
# A5: 약관을 쉽게 이용할 수 있는 꿀팁으로는 다음과 같은 5가지가 있습니다:
# 1. 시각화된 '약관 요약내용' 활용: 계약 일반사항, 가입시 유의사항, 민원사례 등을 쉽게 이해할 수 있습니다. (약관 요약내용 P7~P15)
# 2. '약관 핵심 체크항목 쉽게 찾기' 이용: 약관 내용 중 핵심적인 권리 및 의무관계를 쉽게 찾을 수 있습니다. (핵심 체크항목 P5)
# 3. 용어해설 참고: 약관 내용 중 어려운 보험용어는 용어해설, 약관본문 Box 안 예시 등을 참고하면 도움이 됩니다. (용어해설 P16)
# 4. '관련법규' 항목 활용: 약관에서 인용한 법률 조항 및 규정을 자세히 알 수 있습니다. (부록참조)
# 5. 음영·컬러화 또는 진하게 표시된 부분 주의: 보험금 지급 등 약관 주요 내용이므로 주의 깊게 읽어야 합니다.
# 추가로, 기타 문의사항은 보험회사 홈페이지나 고객 콜센터를 통해 문의할 수 있으며, 보험상품 거래단계별 필요한 금융꿀팁 또는 핵심정보는 금융감독원 금융소비자정보 포털에서 확인할 수 있습니다.
# 출처: ['page_6.png']
#
# Q1: 해약환급금에 대한 정보는 어느 조항에서 확인할 수 있나요?
# A1: 해약환급금에 대한 정보는 제36조(계약자의 임의해지 및 피보험자의 서면동의 철회권) P29와 제39조(해약환급금) P30에서 확인할 수 있습니다. 이와 관련된 영상자료는 QR 코드를 스캔하여 볼 수 있습니다.
# 출처: ['page_6.png']
#
# Q2: '무배당THE 건강한치아보험V(갱신형)' 상품의 특징은 무엇인가요?
# A2: '무배당THE 건강한치아보험V(갱신형)' 상품의 특징은 다음과 같습니다:
# - 무배당: 계약자에게 배당을 하지 않는 상품입니다.
# - 치아보험: 피보험자의 질병 또는 재해에 대한 위험을 보장하는 상품입니다.
# - 갱신형: 보험계약 갱신 시 연령의 증가, 위험률 변동 등으로 보험료가 인상될 수 있는 상품입니다.
# 출처: ['page_7.png']
#
# Q3: 보험금 지급에 있어 면책기간과 감액지급이란 무엇인가요?
# A3: 면책기간은 보험금이 지급되지 않는 기간을 말하며, '무배당THE 건강한치아보험V(갱신형)'에서는 충전치료보험금과 크라운치료보험금의 경우 가입 후 90일간 보장이 제외됩니다. 감액지급은 보험금이 일부만 지급되는 것을 의미하며, 같은 담보의 경우 가입 후 1년간 보험금의 50%만 지급됩니다. 단, 재해로 인한 치과치료의 경우 계약일부터 해당 치료보험금의 100%를 지급하며, 갱신계약은 면책기간과 감액지급이 없습니다.
# 출처: ['page_7.png']
#
# Q4: 보험상품 거래단계별 필요한 금융꿀팁이나 핵심정보는 어디에서 확인할 수 있나요?
# A4: 보험상품 거래단계별 필요한 금융꿀팁이나 핵심정보는 금융감독원 금융소비자정보 포털(FINE, fine.fss.or.kr)에서 확인할 수 있습니다. 이 포털은 금융상품에 대한 다양한 정보를 제공하여 소비자가 보다 현명한 결정을 내릴 수 있도록 돕습니다.
# 출처: ['page_6.png']
#
# Q5: 보험약관에서 음영·컬러화 되거나 진하게 표시된 부분의 중요성은 무엇인가요?
# A5: 보험약관에서 음영·컬러화 되거나 진하게 표시된 부분은 보험금 지급 등 약관의 주요 내용을 나타내므로, 이러한 부분은 특히 주의 깊게 읽어야 합니다. 이는 중요한 정보를 강조하여 소비자가 약관의 핵심 사항을 놓치지 않도록 돕기 위함입니다.
# 출처: ['page_6.png']
#
# Q1: 보험금 지급 한도는 어떻게 설정되어 있나요?
# A1: '무배당THE 건강한치아보험V(갱신형)'에서는 보험금 지급 한도가 설정된 담보가 있습니다. 예를 들어, 크라운치료보험금의 경우 계약일부터 2년 미만인 유치 및 영구치에 대해서는 연간 3개를 한도로 지급하며, 계약일부터 2년 이후에는 개수 제한 없이 지급합니다. 이러한 보장한도는 소비자가 보험금을 청구할 때 고려해야 할 중요한 사항입니다.
# 출처: ['page_8.png']
#
# Q2: 치과치료 관련 보험금을 지급하지 않는 경우는 어떤 경우인가요?
# A2: 치과치료 관련 보험금은 다음과 같은 경우에 지급하지 않습니다:
# ㄱ. 치과치료보장개시일 전에 해당 치과치료를 진단확정 받은 경우
# ㄴ. 치아 교모증, 치경부 마모증, 치열교정 준비 등 "치아우식증(충치), 치주질환(잇몸질환) 또는 재해" 이외의 원인으로 치과치료를 받은 경우
# ㄷ. 다른 치과치료를 위하여 임시 치과치료를 한 경우
# ㄹ. 이미 충전치료, 크라운치료를 받은 부위에 대하여 새로운 "치아우식증(충치), 치주질환(잇몸질환) 또는 재해"를 원인으로 하지 않는 수리, 복구, 대체치료를 한 경우
# ㅁ. 라미네이트, 잇몸성형 등 미용 상의 치료
# 이러한 유의사항은 보험금 청구 시 보험회사가 지급을 거절할 수 있는 사유들을 명시하고 있으므로, 소비자는 이를 숙지하고 있어야 합니다.
# 출처: ['page_8.png']
#
# Q3: 동일한 치아에 대해 여러 치과치료를 받은 경우 보험금은 어떻게 지급되나요?
# A3: 동일한 치아에 대해 동시에 충전치료, 크라운치료 중 두 가지 이상의 치과치료를 포함하는 복합형태의 치료를 받은 경우, 해당 치료보험금 중 가장 높은 한 가지의 해당 치료보험금을 지급합니다. 이는 중복된 치료에 대해 중복 지급을 방지하고, 가장 높은 보장을 제공하는 한 가지 치료에 대해서만 보험금을 지급하는 정책입니다.
# 출처: ['page_8.png']
#
# Q4: 보험계약을 중도에 해지할 경우 해약환급금은 어떻게 계산되나요?
# A4: 보험계약자가 보험계약을 중도에 해지할 경우, 보험회사는 해약환급금을 지급합니다. 해약환급금은 납입한 보험료에서 계약체결 및 유지관리 등에 소요되는 경비와 경과된 기간의 위험 보장에 사용된 보험료를 차감하여 계산됩니다. 따라서 해약환급금은 납입한 보험료보다 적거나 없을 수도 있습니다. 이는 계약자가 계약을 해지할 때 재정적으로 고려해야 할 중요한 사항입니다.
# 출처: ['page_8.png']
#
# Q5: 보험금 지급 유의사항에는 어떤 내용이 포함되어 있나요?
# A5: 보험금 지급 유의사항에는 면책기간, 감액지급, 보장한도 등이 포함되어 있습니다. 면책기간은 보험금이 지급되지 않는 기간을 의미하며, 감액지급은 보험금이 일부만 지급되는 조건을 말합니다. 보장한도는 보험금 지급의 최대 한도를 설정하는 것을 의미합니다. 이러한 유의사항은 보험금 청구 시 소비자가 알아야 할 중요한 정보이므로, 상품설명서 및 약관을 참조하여 자세한 사항을 확인해야 합니다.
# 출처: ['page_7.png']
#
# Q6: 보험 갱신 시 보험료가 변동될 수 있는 이유는 무엇인가요?
# A6: 이 보험은 갱신형 계약으로, 갱신 시 보험료가 변동될 수 있습니다. 보험료의 인상 가능성은 연령의 증가, 위험률 변동 등에 기인합니다. 따라서 보험 가입자는 갱신 시 보험료가 인상될 수 있다는 점을 주의해야 합니다.
# 출처: ['page_9.png']
#
# Q7: 보장성보험의 주요 특성에는 어떤 것들이 있나요?
# A7: 보장성보험의 주요 특성은 질병 또는 재해에 대한 위험 보장을 주목적으로 하며, 저축이나 연금수령을 목적으로 가입하기에는 적합하지 않다는 점입니다. 또한, 만기 또는 중도해지 시 납입한 보험료보다 환급금이 적을 수 있다는 점도 주요 특성 중 하나입니다.
# 출처: ['page_9.png']
#
# Q8: 예금자보호제도는 보험 상품에 어떻게 적용되나요?
# A8: 예금자보호제도는 해약환급금(또는 만기 시 보험금)에 기타지급금을 합한 금액에 대해 1인당 최대 "5천만원까지" 보호합니다. 이는 본 보험회사의 여타 보호상품과 합산된 금액에 적용됩니다. 또한, 본 보험회사 보호상품의 사고보험금을 합산한 금액도 1인당 "5천만원까지" 보호됩니다. 이는 보험 가입자가 보험 상품을 선택할 때 고려해야 할 중요한 보호 장치입니다.
# 출처: ['page_9.png']
#
# Q9: 보험계약을 해지할 때 해약환급금이 납입한 보험료보다 적거나 없을 수 있는 이유는 무엇인가요?
# A9: 보험계약을 해지할 때 해약환급금이 납입한 보험료보다 적거나 없을 수 있는 이유는 해약환급금 계산 시 납입한 보험료에서 계약체결 및 유지관리에 소요되는 경비와 경과된 기간의 위험 보장에 사용된 보험료를 차감하기 때문입니다. 이는 보험계약자가 중도해지를 고려할 때 재정적인 손실을 감안해야 하는 중요한 사항입니다.
# 출처: ['page_8.png']
#
# Q10: 보험금 지급 시 가장 높은 한 가지 치료보험금만 지급하는 이유는 무엇인가요?
# A10: 동일한 치아에 대해 동시에 여러 치과치료를 받은 경우, 가장 높은 한 가지 치료보험금만 지급하는 이유는 중복된 치료에 대해 중복 지급을 방지하고, 가장 높은 보장을 제공하기 위함입니다. 이는 보험회사가 보험금 지급을 효율적으로 관리하고, 보험 가입자에게 최적의 보장을 제공하기 위한 정책입니다.
# 출처: ['page_8.png']
