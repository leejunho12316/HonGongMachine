# %% [markdown]
# <a href="https://colab.research.google.com/github/leejunho12316/HonGongMachine/blob/main/RAGAS_Quick_Start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ragas

# !ragas quickstart rag_eval

# %cd rag_eval

# !pip install -e .
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.5/466.5 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 49.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.7/506.7 kB 31.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 84.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.8/358.8 kB 18.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 47.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
# ...

# %%
import os
os.environ['OPENAI_API_KEY']=""

# %%
#evals.py 실행
# !python rag_eval/evals.py
# Out:
# /usr/local/lib/python3.12/dist-packages/instructor/providers/gemini/client.py:5: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai  # type: ignore[import-not-found]
# dataset loaded successfully Dataset(name=test_dataset,  len=3)
# Running experiment:   0% 0/3 [00:00<?, ?it/s]RAG traces exported to: evals/logs/rag_run_20260328_024931_9095_2026-03-28T02-49-32-915611.json
# RAG traces exported to: evals/logs/rag_run_20260328_024934_3285_2026-03-28T02-49-35-121089.json
# RAG traces exported to: evals/logs/rag_run_20260328_024936_0183_2026-03-28T02-49-37-278808.json
# Running experiment: 100% 3/3 [00:06<00:00,  2.19s/it]
# Experiment completed successfully!
# ...

# %%
# %cd rag_eval
# !python evals.py
# Out:
# /content/rag_eval
# /usr/local/lib/python3.12/dist-packages/instructor/providers/gemini/client.py:5: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai  # type: ignore[import-not-found]
# dataset loaded successfully Dataset(name=test_dataset,  len=3)
# Running experiment:   0% 0/3 [00:00<?, ?it/s]RAG traces exported to: evals/logs/rag_run_20260328_025259_1356_2026-03-28T02-53-01-500301.json
# RAG traces exported to: evals/logs/rag_run_20260328_025302_4503_2026-03-28T02-53-02-957106.json
# RAG traces exported to: evals/logs/rag_run_20260328_025303_0169_2026-03-28T02-53-04-345738.json
# Running experiment: 100% 3/3 [00:06<00:00,  2.05s/it]
# Experiment completed successfully!
# ...

# %%
# !pip install ragas[examples]
# !python -m ragas_examples.prompt_evals.prompt
# Out:
# ...
# WARNING: ragas 0.4.3 does not provide the extra 'examples'
# ...
# /usr/bin/python3: Error while finding module specification for 'ragas_examples.prompt_evals.prompt' (ModuleNotFoundError: No module named 'ragas_examples')

# %%
import pandas as pd

samples = [{"text": "I loved the movie! It was fantastic.", "label": "positive"},
    {"text": "The movie was terrible and boring.", "label": "negative"},
    {"text": "It was an average film, nothing special.", "label": "positive"},
    {"text": "Absolutely amazing! Best movie of the year.", "label": "positive"}]
pd.DataFrame(samples).to_csv("test_dataset.csv", index=False)

# %%
from ragas.metrics import discrete_metric
from ragas.metrics.result import MetricResult

@discrete_metric(name="accuracy", allowed_values=["pass", "fail"])
def my_metric(prediction: str, actual: str):
    """Calculate accuracy of the prediction."""
    return MetricResult(value="pass", reason="") if prediction == actual else MetricResult(value="fail", reason="")
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
from ragas import experiment

@experiment()
async def run_experiment(row):

    response = run_prompt(row["text"])
    score = my_metric.score(
        prediction=response,
        actual=row["label"]
    )

    experiment_view = {
        **row,
        "response":response,
        "score":score.value,
    }
    return experiment_view

# %%
@experiment()
async def run_experiment(row, model):
    response = run_prompt(row["text"], model=model)
    score = my_metric.score(
        prediction=response,
        actual=row["label"]
    )

    experiment_view = {
        **row,
        "response": response,
        "score": score.value,
    }
    return experiment_view

# Run with specific parameters
run_experiment.arun(dataset, "gpt-4")

# Or use keyword arguments
run_experiment.arun(dataset, model="gpt-4o")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14016/4212058383.py in <cell line: 0>()
#      15
#      16 # Run with specific parameters
# ---> 17 run_experiment.arun(dataset, "gpt-4")
#      18
#      19 # Or use keyword arguments
#
# NameError: name 'dataset' is not defined

# %%
# !python -m ragas_examples.prompt_evals.evals
# Out:
# /usr/bin/python3: Error while finding module specification for 'ragas_examples.prompt_evals.evals' (ModuleNotFoundError: No module named 'ragas_examples')

# %%
# !python -m ragas_examples.prompt_evals.prompt
# Out:
# /usr/bin/python3: Error while finding module specification for 'ragas_examples.prompt_evals.prompt' (ModuleNotFoundError: No module named 'ragas_examples')
