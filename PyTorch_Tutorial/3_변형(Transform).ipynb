# %% [markdown]
# <a href="https://colab.research.google.com/github/leejunho12316/HonGongMachine/blob/main/PyTorch_Tutorial/3_%EB%B3%80%ED%98%95(Transform).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torchvision import datasets
from torchvision.transforms import ToTensor, Lambda

# %%
ds = datasets.FashionMNIST(
    root = 'data',
    train = True,
    download = True,
    transform = ToTensor(), #numpy, ndarray, PIL Image -> FloatTensor, 범위 0~1로 조정
    target_transform = Lambda(lambda y : torch.zeros(10, dtype=torch.float).scatter_(0, torch.tensor(y), value=1))

)
# Out:
# 100%|██████████| 26.4M/26.4M [00:02<00:00, 12.8MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 203kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.77MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 11.5MB/s]
