# %% [markdown]
# <a href="https://colab.research.google.com/github/leejunho12316/HonGongMachine/blob/main/AICE_Chapter_08_%EC%84%A0%ED%98%95%ED%9A%8C%EA%B7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/국민건강보험공단_건강검진정보_20211231_수정.CSV', encoding='cp949')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    기준년도  가입자일련번호  시도코드  성별  연령대코드(5세단위)  신장(5cm단위)  체중(5kg단위)  허리둘레  시력(좌)  \
# 0  2021  4400892    41   1           10        160         65  86.4    1.0
# 1  2021  2358945    41   1            8        175         90  94.0    1.0
# 2  2021  2369829    41   1           13        160         55  80.0    1.0
# 3  2021  1761219    41   2           10        155         50  74.0    1.0
# 4  2021  2312054    41   2           11        155         65  80.0    1.0
#
#    시력(우)  청력(좌)  청력(우)  수축기혈압  이완기혈압  식전혈당(공복혈당)  총콜레스테롤  트리글리세라이드  HDL콜레스테롤  \
# 0    1.0    1.0    1.0  110.0   72.0       179.0     NaN       NaN       NaN
# 1    1.0    1.0    1.0  126.0   76.0        86.0     NaN       NaN       NaN
# 2    1.0    1.0    1.0  183.0  109.0       115.0     NaN       NaN       NaN
# 3    1.0    1.0    1.0  166.0  115.0       102.0     NaN       NaN       NaN
# 4    1.0    1.0    1.0  135.0   70.0        86.0     NaN       NaN       NaN
#
# ...

# %%
df.drop(['치아우식증유무','치석','시력(좌)', '시력(우)', '청력(좌)', '청력(우)','구강검진수검여부'], axis=1, inplace=True)

# %%
df.drop(['기준년도','가입자일련번호','성별','시도코드'], axis=1, inplace=True)

# %% [markdown]
# #데이터 분배

# %%
print(df.shape)
df.head(3)
# Out:
# (1000000, 19)
#    연령대코드(5세단위)  신장(5cm단위)  체중(5kg단위)  허리둘레  수축기혈압  이완기혈압  식전혈당(공복혈당)  총콜레스테롤  \
# 0           10        160         65  86.4  110.0   72.0       179.0     NaN
# 1            8        175         90  94.0  126.0   76.0        86.0     NaN
# 2           13        160         55  80.0  183.0  109.0       115.0     NaN
#
#    트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  혈청지오티(AST)  혈청지피티(ALT)  \
# 0       NaN       NaN       NaN  14.3  1.0      0.8        18.0        20.0
# 1       NaN       NaN       NaN  16.0  1.0      0.8        58.0       144.0
# 2       NaN       NaN       NaN  13.8  1.0      0.8        32.0        26.0
#
#    감마지티피  흡연상태  음주여부
# 0   28.0   1.0   1.0
# 1   74.0   1.0   1.0
# 2   38.0   1.0   1.0

# %%
train = df.dropna(axis=0)
test = df[df['LDL콜레스테롤'].isnull()]

x = train.drop('LDL콜레스테롤', axis=1)
y = train['LDL콜레스테롤']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (230252, 18) (113409, 18) (230252,) (113409,)

# %% [markdown]
# #학습

# %%
from sklearn.linear_model import LinearRegression

#모델 만들기
reg = LinearRegression()
reg.fit(X_train, y_train)
print(f"결과 - coef : {reg.coef_}, intercept : {reg.intercept_}")
print()
for i in range(len(reg.coef_)):
  print(X_train.columns[i], " : ", reg.coef_[i])
# Out:
# 결과 - coef : [ 0.07504877  0.02436839  0.03984692  0.07006197 -0.01134489 -0.0169368
#  -0.00398696  0.96371436 -0.17038637 -0.66997818  0.15014143  0.06685567
#   0.11166802 -0.01565601  0.0122948  -0.00499188  0.19822968 -0.8545701 ], intercept : -27.041384181425443
#
# 연령대코드(5세단위)  :  0.07504876582677455
# 신장(5cm단위)  :  0.02436838624290849
# 체중(5kg단위)  :  0.039846923580407693
# 허리둘레  :  0.07006197239231851
# 수축기혈압  :  -0.01134489461360145
# 이완기혈압  :  -0.016936802963822776
# 식전혈당(공복혈당)  :  -0.003986960487338668
# 총콜레스테롤  :  0.9637143587698423
# 트리글리세라이드  :  -0.17038637340316576
# HDL콜레스테롤  :  -0.6699781830563377
# 혈색소  :  0.15014143013055298
# 요단백  :  0.06685566529591505
# 혈청크레아티닌  :  0.11166801919216951
# 혈청지오티(AST)  :  -0.015656006321437217
# 혈청지피티(ALT)  :  0.012294803445864196
# 감마지티피  :  -0.004991882110849657
# 흡연상태  :  0.1982296777847982
# 음주여부  :  -0.8545700979015762

# %%
#validation 하기
y_pred = reg.predict(X_test)

from sklearn.metrics import mean_squared_error
#from sklearn.metrics import root_mean_squared_error

rmse = mean_squared_error(y_test, y_pred)
print(rmse)
# Out:
# 51.96327058869079

# %% [markdown]
# # 학습 - 중요한 칼럼 삭제해서

# %%
x.columns
# Out:
# Index(['연령대코드(5세단위)', '신장(5cm단위)', '체중(5kg단위)', '허리둘레', '수축기혈압', '이완기혈압',
#        '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', '혈색소', '요단백', '혈청크레아티닌',
#        '혈청지오티(AST)', '혈청지피티(ALT)', '감마지티피', '흡연상태', '음주여부'],
#       dtype='object')

# %%
x.drop(['총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤'], axis=1, inplace=True)

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33, random_state=442)

# %%
lr = LinearRegression()
reg = lr.fit(X_train, y_train)

print(f"결과 - coef : {reg.coef_}, intercept : {reg.intercept_}")
print()
for i in range(len(reg.coef_)):
  print(X_train.columns[i], " : ", reg.coef_[i])
# Out:
# 결과 - coef : [-1.35453551 -0.4210992   0.13978434 -0.15483862 -0.20417763  0.38921992
#  -0.12456819  3.33934953 -0.90177458 -0.44927597 -0.08090026  0.05938285
#  -0.00384169 -2.72067405 -0.01032614], intercept : 171.01541771837725
#
# 연령대코드(5세단위)  :  -1.354535513909419
# 신장(5cm단위)  :  -0.42109919694664283
# 체중(5kg단위)  :  0.13978434392927921
# 허리둘레  :  -0.15483861955808856
# 수축기혈압  :  -0.20417763191362717
# 이완기혈압  :  0.3892199212168899
# 식전혈당(공복혈당)  :  -0.12456818888786286
# 혈색소  :  3.3393495271992704
# 요단백  :  -0.901774578499214
# 혈청크레아티닌  :  -0.4492759709550043
# 혈청지오티(AST)  :  -0.08090026434766795
# 혈청지피티(ALT)  :  0.05938285143343434
# 감마지티피  :  -0.003841687993334633
# 흡연상태  :  -2.720674050171452
# 음주여부  :  -0.010326143923551257

# %%
#validation
y_pred = reg.predict(X_test)

res = mean_squared_error(y_pred, y_test)
print(res)
# Out:
# 1380.487739884061
