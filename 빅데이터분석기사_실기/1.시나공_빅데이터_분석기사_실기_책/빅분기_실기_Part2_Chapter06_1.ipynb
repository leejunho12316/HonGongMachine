# %% [markdown]
# <a href="https://colab.research.google.com/github/leejunho12316/HonGongMachine/blob/main/%EB%B9%85%EB%B6%84%EA%B8%B0_%EC%8B%A4%EA%B8%B0_Part2_Chapter06_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
train = pd.read_csv('diabetes_train.csv')
test = pd.read_csv('diabetes_test.csv')

# %% [markdown]
# #EDA

# %%
print("shape: ", train.shape, test.shape)
print("null: ", train.isnull().sum().sum(), test.isnull().sum().sum())

display(train.head(3))
display(test.head(3))
# Out:
# (614, 9) (154, 8)
# 0 0
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1      118             58             36       94  33.3
# 1            3      173             78             39      185  33.8
# 2            4      109             64             44       99  34.8
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.261   23        0
# 1                     0.970   31        1
# 2                     0.905   26        1
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            3      102             74              0        0  29.5
# 1            5      104             74              0        0  28.8
# 2            4       95             70             32        0  32.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.121   32
# 1                     0.153   48
# 2                     0.612   24

# %%
train.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   614.000000  614.000000     614.000000     614.000000  614.000000
# mean      3.789902  120.659609      69.366450      20.969055   80.382736
# std       3.384519   32.556686      18.847224      15.923677  111.332249
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.500000       0.000000    0.000000
# 50%       3.000000  116.000000      72.000000      23.000000   36.000000
# 75%       6.000000  140.750000      80.000000      32.000000  128.750000
# max      17.000000  199.000000     122.000000      99.000000  680.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  614.000000                614.000000  614.000000  614.000000
# mean    32.067427                  0.475490   33.250814    0.343648
# std      7.888971                  0.326519   11.789160    0.475313
# ...

# %%
test.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   154.000000  154.000000     154.000000     154.000000  154.000000
# mean      4.064935  121.831169      68.064935      18.811688   77.474026
# std       3.311054   29.611163      21.297358      16.001131  130.046960
# min       0.000000   56.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.500000       0.000000    0.000000
# 50%       3.000000  119.500000      70.000000      20.500000    0.000000
# 75%       6.000000  139.750000      80.000000      32.000000  105.750000
# max      13.000000  197.000000     114.000000      50.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  154.000000                154.000000  154.000000
# mean    31.694156                  0.457468   33.201299
# std      7.883533                  0.350588   11.682275
# min      0.000000                  0.085000   21.000000
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               614 non-null    int64
#  1   Glucose                   614 non-null    int64
#  2   BloodPressure             614 non-null    int64
#  3   SkinThickness             614 non-null    int64
#  4   Insulin                   614 non-null    int64
#  5   BMI                       614 non-null    float64
#  6   DiabetesPedigreeFunction  614 non-null    float64
#  7   Age                       614 non-null    int64
#  8   Outcome                   614 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 43.3 KB

# %% [markdown]
# #데이터 전처리

# %%
target = train.pop('Outcome')

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train = scaler.fit_transform(train)
test = scaler.transform(test)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(train, target, test_size=0.3, random_state = 99)

print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
# Out:
# (429, 8) (429,) (185, 8) (185,)

# %% [markdown]
# #모델 학습

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 100, max_depth=50, min_samples_split=2, random_state = 99)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=50, random_state=99)

# %%
from sklearn.metrics import roc_auc_score

y_pred = rfc.predict(X_val)
score = roc_auc_score(y_val, y_pred)
print('score : ', score)

y_pred2 = rfc.predict_proba(X_val)
score2 = roc_auc_score(y_val, y_pred2[:,1])
print('score2 : ', score2)

print()
print(y_pred[:10])
print(y_pred2[:10])
# Out:
# score :  0.6748722087705138
# score2 :  0.7984934086629003
#
# [1 1 1 1 0 0 0 0 1 0]
# [[0.48 0.52]
#  [0.12 0.88]
#  [0.11 0.89]
#  [0.31 0.69]
#  [0.68 0.32]
#  [0.79 0.21]
#  [0.65 0.35]
#  [0.87 0.13]
#  [0.48 0.52]
#  [0.97 0.03]]

# %% [markdown]
# #test 저장

# %%
pred = rfc.predict_proba(test)

#저장
submit = pd.DataFrame({'pred' : pred[:,1]})
submit.to_csv('result.csv', index=False)

#불러와서 마지막 확인
s = pd.read_csv('result.csv')
s
# Out:
#      pred
# 0    0.20
# 1    0.19
# 2    0.13
# 3    0.04
# 4    0.10
# ..    ...
# 149  0.40
# 150  0.29
# 151  0.02
# 152  0.61
# 153  0.44
#
# [154 rows x 1 columns]
